# %% [markdown]
# # **Data Augmentation** using Variational Autoencoder
#
# This notebook will guide you trough the use of a variational convolutional autoencoder in the task of data augmentation. The main objective is to use a convolutional autoencoder to reconstruct of the **"2"** images in the MNIST database in order to augment a database. (You can try different digits)

# %% [markdown]
# ## A little bit about Autoencoder in general
#
# Autoencoder's goal is to learn how to reconstruct the input-data. But how is it helpful? The trick is their structure. The first part of the network is what we refer to as the Encoder. It receives the input and it encodes it in a latent space of a lower dimension. The second part (the Decoder) takes that vector and decode it in order to produce the original input.
#
# Therefore, we can apply them to reproduce the same but a little different or even better data. Examples are:
#
# ***Data Denoising***: Feed them with a noisy image and train them to output the same image but without the noise
#
# ***Training data augmentation***
#
# ***Anomaly Detection***: Train them on a single class so that every anomaly gives a large reconstruction error.
#
# Variational autoencoders are trained to learn the probability distribution that models the input-data and not the function that maps the input and the output. It then samples points from this distribution and feed them to the decoder to generate new input data samples.
#
# One of the key aspects of VAE is the **loss function**. Most commonly, it consists of two components. The reconstruction loss measures how different the reconstructed data are from the original data (binary cross entropy for example).
# [Reference : Sergios Karagiannakos]

# %% [markdown]
# ### Load the packages

# %%
# ============== Packages ===================
# %%capture
# %pip install bff
# %pip install --upgrade tensorflow
import re
import bff
import math
import pickle
import pprint
import statistics
import numpy as np
import collections
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import bff.plot as bplt
from pathlib import Path
import matplotlib as mpl
from itertools import cycle
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from sklearn import preprocessing
import matplotlib.patches as mpatches
from typing import Callable, Dict, List, Sequence, Tuple, Union
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Imports for model
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import mse, binary_crossentropy, MeanSquaredError
from tensorflow.keras.layers import Layer, Dense, Reshape, Conv2D, Conv2DTranspose, Flatten, MaxPooling2D, UpSampling2D

# %% [markdown]
# ### Loading MNIST dataset for digit "***2***"
#
# The MNIST is database of handwritten digits. The digits have been size-normalized and centered in a fixed-size image.
#
# In this section we also split our data into training and testing datasets.
#
# You are able to observe different digits.

# %%
# Loading MNIST dataset for especific number, you can change digit in num variable
num = 2

# MNIST dataset.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Select only number that choose in num.
train_filter = np.where((y_train == num))
test_filter = np.where((y_test == num))
x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

print(f'Size of train: {y_train.shape}')
print(f'Size of test: {y_test.shape}')

# Resize the images and normalize between [0, 1].
image_size = x_train.shape[1]
x_train = x_train.reshape(x_train.shape[0], image_size, image_size, 1).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], image_size, image_size, 1).astype('float32') / 255
print(f'Shape of training: {x_train.shape}')
print(f'Shape of testing: {x_test.shape}')
# Out:
# Size of train: (5958,)
# Size of test: (1032,)
# Shape of training: (5958, 28, 28, 1)
# Shape of testing: (1032, 28, 28, 1)

# %% [markdown]
# ### Examples of digit ***"2"*** from dataset

# %%
# Examples of 2
_, axes = plt.subplots(10, 10, figsize=(10, 10))

for i, ax in enumerate(tqdm(axes.flatten())):
  ax.xaxis.set_major_locator(plt.NullLocator())
  ax.yaxis.set_major_locator(plt.NullLocator())
  if len(x_train.shape) < 3:
      size = int(np.sqrt(x_train[i].shape[0]))
  else:
      size = x_train.shape[1]
  ax.imshow(x_train[i].reshape(size, size), cmap='gray_r')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1786.23it/s]

# %% [markdown]
# ### Reconstructing Variational Autoencoder

# %%
class Sampling(Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a serie."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        # By default, random_normal has mean=0 and std=1.0.
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class Encoder(Layer):
    """Maps series to a triplet (z_mean, z_log_var, z)."""

    def __init__(self,
                 latent_dim=2,
                 name='encoder',
                 **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        self.conv_1 = Conv2D(filters=32, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_2 = Conv2D(filters=64, kernel_size=3, activation='relu', strides=2, padding='same')
        self.flatten = Flatten()
        self.dense_before_latent = Dense(16, activation='relu')
        self.dense_mean = Dense(latent_dim, name='z_mean')
        self.dense_log_var = Dense(latent_dim, name='z_log_var')
        self.sampling = Sampling()
  
    def call(self, inputs):
        x = self.conv_1(inputs)
        x = self.conv_2(x)
        shape = K.int_shape(x)
        #print(K.int_shape(x))
        # Generate latent vector.
        x = self.flatten(x)
        x = self.dense_before_latent(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z


class Decoder(Layer):
    """Converts z, the encoded vector, back into a readable series."""
  
    def __init__(self,
                 original_dim,
                 name='decoder',
                 **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)
        self.dense_proj = Dense(7*7*64, activation='relu')
        self.reshape = Reshape(target_shape=(7, 7, 64))
        self.conv_1 = Conv2DTranspose(filters=64, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_2 = Conv2DTranspose(filters=32, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_output = Conv2DTranspose(filters=1, kernel_size=3, activation='sigmoid', padding='same')
  
    def call(self, inputs):
        x = self.dense_proj(inputs)
        x = self.reshape(x)
        x = self.conv_1(x)
        x = self.conv_2(x)
        return self.conv_output(x)


class VariationalAutoEncoder(Model):
    """Combines the encoder and decoder into an end-to-end model for training."""
  
    def __init__(self,
                 original_dim,
                 latent_dim=32,
                 name='autoencoder',
                 **kwargs):
        super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
        self.original_dim = original_dim
        self.encoder = Encoder(latent_dim=latent_dim)
        self.decoder = Decoder(original_dim)
  
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        
        # Add KL divergence regularization loss.
        reconstruction_loss = binary_crossentropy(K.flatten(inputs), K.flatten(reconstructed))
        reconstruction_loss *= self.original_dim
        kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        kl_loss = K.sum(kl_loss, axis=-1)
        kl_loss *= -0.5
        vae_loss = K.mean(reconstruction_loss + kl_loss)
        self.add_loss(vae_loss)
        
        return reconstructed

# %% [markdown]
# ### Different sizes of dataset for fitting the variational autoencoder
#
# In this step, you fit variational autoencoder model to different sizes of train dataset:
#
# 1.   *whole dataset*
# 2.   *1000 samples of dataset*
# 3.   *100 samples of dataset*
# 4.   *10 samples of dataset*
#
#
# Observe different sizes of samples and their model losses.

# %%
models = {}

training_sizes = [x_train.shape[0], 1000, 100, 10] # different sizes of train dataset

for size_training in training_sizes:
    #size_training = x_train.shape[0]
    x_train_filter = x_train[:size_training]

    print(f'Training using {size_training} examples.')
    print(f'Shape of training: {x_train_filter.shape}')

    # Size of layers
    original_dim = x_train_filter.shape[1] # Should be 784.
    latent_dim = 2

    # Parameters for training.
    batch_size = 16 if size_training > 100 else 1
    epochs = 50

    vae = VariationalAutoEncoder(original_dim, 
                                 latent_dim=latent_dim)

    optimizer = Adam(learning_rate=1e-3)

    # Define the Keras TensorBoard callback.
    #logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
    #tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

    # Losses are MSE with KL divergence.
    vae.compile(optimizer)
    history = vae.fit(x_train_filter,
                      epochs=epochs, 
                      batch_size=batch_size, 
                      validation_split=0.2, 
                      verbose=1)
                      #callbacks=[tensorboard_callback])
    #plot_model(vae, to_file='vae-cnn.png')
    vae.summary()
    
    models[size_training] = (history, vae)


#plot_model(vae, to_file='11-VAE_MLP_-OBJ.png', show_shapes=True, expand_nested=True)
# Out:
# Training using 5958 examples.
# Shape of training: (5958, 28, 28, 1)
# Epoch 1/50
# 298/298 [==============================] - 6s 17ms/step - loss: 8.5206 - val_loss: 7.3731
# Epoch 2/50
# 298/298 [==============================] - 5s 17ms/step - loss: 7.3627 - val_loss: 7.2972
# Epoch 3/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.3054 - val_loss: 7.2626
# Epoch 4/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2979 - val_loss: 7.2609
# Epoch 5/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2910 - val_loss: 7.2561
# Epoch 6/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2883 - val_loss: 7.2763
# Epoch 7/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2860 - val_loss: 7.2394
# Epoch 8/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2867 - val_loss: 7.2420
# Epoch 9/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2878 - val_loss: 7.2503
# Epoch 10/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2869 - val_loss: 7.2350
# Epoch 11/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2842 - val_loss: 7.2437
# Epoch 12/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2838 - val_loss: 7.2443
# Epoch 13/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2833 - val_loss: 7.2373
# Epoch 14/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2809 - val_loss: 7.2483
# Epoch 15/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2808 - val_loss: 7.2504
# Epoch 16/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2838 - val_loss: 7.2527
# Epoch 17/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2819 - val_loss: 7.2485
# Epoch 18/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2787 - val_loss: 7.2443
# Epoch 19/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2796 - val_loss: 7.2389
# Epoch 20/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2784 - val_loss: 7.2377
# Epoch 21/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2787 - val_loss: 7.2443
# Epoch 22/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2804 - val_loss: 7.2414
# Epoch 23/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2770 - val_loss: 7.2425
# Epoch 24/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2784 - val_loss: 7.2524
# Epoch 25/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2791 - val_loss: 7.2469
# Epoch 26/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2773 - val_loss: 7.2538
# Epoch 27/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2789 - val_loss: 7.2541
# Epoch 28/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2783 - val_loss: 7.2472
# Epoch 29/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2790 - val_loss: 7.2368
# Epoch 30/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2767 - val_loss: 7.2361
# Epoch 31/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2762 - val_loss: 7.2402
# Epoch 32/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2766 - val_loss: 7.2352
# Epoch 33/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2762 - val_loss: 7.2378
# Epoch 34/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2787 - val_loss: 7.2366
# Epoch 35/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2762 - val_loss: 7.2414
# Epoch 36/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2754 - val_loss: 7.2435
# Epoch 37/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2749 - val_loss: 7.2486
# Epoch 38/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2746 - val_loss: 7.2510
# Epoch 39/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2760 - val_loss: 7.2381
# Epoch 40/50
# 298/298 [==============================] - 5s 16ms/step - loss: 7.2752 - val_loss: 7.2471
# Epoch 41/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2748 - val_loss: 7.2389
# Epoch 42/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2761 - val_loss: 7.2388
# Epoch 43/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2758 - val_loss: 7.2422
# Epoch 44/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2746 - val_loss: 7.2364
# Epoch 45/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2761 - val_loss: 7.2412
# Epoch 46/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2737 - val_loss: 7.2417
# Epoch 47/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2742 - val_loss: 7.2491
# Epoch 48/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2752 - val_loss: 7.2358
# Epoch 49/50
# 298/298 [==============================] - 4s 15ms/step - loss: 7.2751 - val_loss: 7.2340
# Epoch 50/50
# 298/298 [==============================] - 5s 15ms/step - loss: 7.2734 - val_loss: 7.2414
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 1000 examples.
# Shape of training: (1000, 28, 28, 1)
# Epoch 1/50
# 50/50 [==============================] - 2s 18ms/step - loss: 13.2014 - val_loss: 8.9064
# Epoch 2/50
# 50/50 [==============================] - 1s 15ms/step - loss: 8.0352 - val_loss: 7.6098
# Epoch 3/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.5323 - val_loss: 7.3900
# Epoch 4/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.4011 - val_loss: 7.3358
# Epoch 5/50
# 50/50 [==============================] - 1s 16ms/step - loss: 7.3609 - val_loss: 7.3042
# Epoch 6/50
# 50/50 [==============================] - 1s 16ms/step - loss: 7.3445 - val_loss: 7.3008
# Epoch 7/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.3089 - val_loss: 7.2761
# Epoch 8/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2987 - val_loss: 7.2309
# Epoch 9/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2655 - val_loss: 7.2258
# Epoch 10/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2628 - val_loss: 7.2248
# Epoch 11/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2502 - val_loss: 7.1994
# Epoch 12/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2395 - val_loss: 7.1968
# Epoch 13/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2419 - val_loss: 7.2287
# Epoch 14/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2313 - val_loss: 7.2224
# Epoch 15/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2365 - val_loss: 7.2138
# Epoch 16/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2234 - val_loss: 7.1857
# Epoch 17/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2283 - val_loss: 7.1960
# Epoch 18/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2287 - val_loss: 7.1838
# Epoch 19/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2257 - val_loss: 7.1992
# Epoch 20/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2246 - val_loss: 7.2059
# Epoch 21/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2292 - val_loss: 7.1900
# Epoch 22/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2292 - val_loss: 7.1965
# Epoch 23/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2254 - val_loss: 7.1970
# Epoch 24/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2195 - val_loss: 7.1865
# Epoch 25/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2196 - val_loss: 7.1808
# Epoch 26/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2147 - val_loss: 7.2012
# Epoch 27/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2210 - val_loss: 7.1870
# Epoch 28/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2179 - val_loss: 7.1877
# Epoch 29/50
# 50/50 [==============================] - 1s 16ms/step - loss: 7.2149 - val_loss: 7.1957
# Epoch 30/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2276 - val_loss: 7.1856
# Epoch 31/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2167 - val_loss: 7.1980
# Epoch 32/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2073 - val_loss: 7.1898
# Epoch 33/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2207 - val_loss: 7.2077
# Epoch 34/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2165 - val_loss: 7.2047
# Epoch 35/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2141 - val_loss: 7.1906
# Epoch 36/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2155 - val_loss: 7.1905
# Epoch 37/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2107 - val_loss: 7.1789
# Epoch 38/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.1996 - val_loss: 7.1811
# Epoch 39/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2296 - val_loss: 7.1635
# Epoch 40/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2050 - val_loss: 7.1852
# Epoch 41/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2076 - val_loss: 7.1793
# Epoch 42/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2088 - val_loss: 7.1551
# Epoch 43/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2226 - val_loss: 7.2120
# Epoch 44/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2242 - val_loss: 7.1751
# Epoch 45/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2063 - val_loss: 7.1917
# Epoch 46/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2062 - val_loss: 7.1783
# Epoch 47/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.1952 - val_loss: 7.1766
# Epoch 48/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.1927 - val_loss: 7.1569
# Epoch 49/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2151 - val_loss: 7.1841
# Epoch 50/50
# 50/50 [==============================] - 1s 15ms/step - loss: 7.2147 - val_loss: 7.1943
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 100 examples.
# Shape of training: (100, 28, 28, 1)
# Epoch 1/50
# 80/80 [==============================] - 1s 5ms/step - loss: 11.9777 - val_loss: 8.8347
# Epoch 2/50
# 80/80 [==============================] - 0s 3ms/step - loss: 8.0267 - val_loss: 8.0284
# Epoch 3/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.6071 - val_loss: 8.0544
# Epoch 4/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.6260 - val_loss: 7.9211
# Epoch 5/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.5274 - val_loss: 7.7591
# Epoch 6/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.5329 - val_loss: 7.7441
# Epoch 7/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.4327 - val_loss: 7.7279
# Epoch 8/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.4318 - val_loss: 7.7486
# Epoch 9/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.4599 - val_loss: 7.6994
# Epoch 10/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3956 - val_loss: 7.8452
# Epoch 11/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.4505 - val_loss: 7.7520
# Epoch 12/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.4142 - val_loss: 7.8188
# Epoch 13/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.4498 - val_loss: 7.7440
# Epoch 14/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3742 - val_loss: 7.7132
# Epoch 15/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3206 - val_loss: 7.8241
# Epoch 16/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3702 - val_loss: 7.6988
# Epoch 17/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3044 - val_loss: 7.6947
# Epoch 18/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3591 - val_loss: 7.8612
# Epoch 19/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3833 - val_loss: 7.7449
# Epoch 20/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3394 - val_loss: 7.7400
# Epoch 21/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3433 - val_loss: 7.7258
# Epoch 22/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3334 - val_loss: 7.7315
# Epoch 23/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2850 - val_loss: 7.9039
# Epoch 24/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3934 - val_loss: 7.7308
# Epoch 25/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3503 - val_loss: 7.6727
# Epoch 26/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2987 - val_loss: 7.6803
# Epoch 27/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3243 - val_loss: 7.6807
# Epoch 28/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3188 - val_loss: 7.7211
# Epoch 29/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2974 - val_loss: 7.6703
# Epoch 30/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3127 - val_loss: 7.6861
# Epoch 31/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3091 - val_loss: 7.8378
# Epoch 32/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3101 - val_loss: 7.7311
# Epoch 33/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3401 - val_loss: 7.6974
# Epoch 34/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2821 - val_loss: 7.9015
# Epoch 35/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3046 - val_loss: 7.7157
# Epoch 36/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3141 - val_loss: 7.8066
# Epoch 37/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3381 - val_loss: 7.6798
# Epoch 38/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2958 - val_loss: 7.6751
# Epoch 39/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3486 - val_loss: 7.7818
# Epoch 40/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3014 - val_loss: 7.7549
# Epoch 41/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2994 - val_loss: 7.6966
# Epoch 42/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3109 - val_loss: 7.7551
# Epoch 43/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3078 - val_loss: 7.7970
# Epoch 44/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3248 - val_loss: 7.7035
# Epoch 45/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2978 - val_loss: 7.7359
# Epoch 46/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2490 - val_loss: 7.7019
# Epoch 47/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2881 - val_loss: 7.8108
# Epoch 48/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3525 - val_loss: 7.7298
# Epoch 49/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.2885 - val_loss: 7.7197
# Epoch 50/50
# 80/80 [==============================] - 0s 3ms/step - loss: 7.3119 - val_loss: 7.7362
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 10 examples.
# Shape of training: (10, 28, 28, 1)
# Epoch 1/50
# 8/8 [==============================] - 1s 29ms/step - loss: 19.1181 - val_loss: 18.5527
# Epoch 2/50
# 8/8 [==============================] - 0s 5ms/step - loss: 17.6172 - val_loss: 15.1268
# Epoch 3/50
# 8/8 [==============================] - 0s 5ms/step - loss: 14.6560 - val_loss: 13.1482
# Epoch 4/50
# 8/8 [==============================] - 0s 5ms/step - loss: 12.8582 - val_loss: 11.3993
# Epoch 5/50
# 8/8 [==============================] - 0s 5ms/step - loss: 11.6469 - val_loss: 10.4831
# Epoch 6/50
# 8/8 [==============================] - 0s 5ms/step - loss: 10.7291 - val_loss: 9.9272
# Epoch 7/50
# 8/8 [==============================] - 0s 5ms/step - loss: 10.1969 - val_loss: 9.4940
# Epoch 8/50
# 8/8 [==============================] - 0s 5ms/step - loss: 9.3782 - val_loss: 9.1352
# Epoch 9/50
# 8/8 [==============================] - 0s 5ms/step - loss: 9.0340 - val_loss: 8.4855
# Epoch 10/50
# 8/8 [==============================] - 0s 5ms/step - loss: 8.5519 - val_loss: 9.6273
# Epoch 11/50
# 8/8 [==============================] - 0s 5ms/step - loss: 8.6667 - val_loss: 8.2526
# Epoch 12/50
# 8/8 [==============================] - 0s 5ms/step - loss: 8.3293 - val_loss: 9.1543
# Epoch 13/50
# 8/8 [==============================] - 0s 5ms/step - loss: 8.3314 - val_loss: 8.1957
# Epoch 14/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.9489 - val_loss: 8.1219
# Epoch 15/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.9227 - val_loss: 8.4220
# Epoch 16/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.7410 - val_loss: 8.1095
# Epoch 17/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.8399 - val_loss: 8.1595
# Epoch 18/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.7614 - val_loss: 8.1806
# Epoch 19/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.9546 - val_loss: 8.2153
# Epoch 20/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.6226 - val_loss: 8.1216
# Epoch 21/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4668 - val_loss: 7.9300
# Epoch 22/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.9587 - val_loss: 8.0478
# Epoch 23/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.5352 - val_loss: 8.1851
# Epoch 24/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.6559 - val_loss: 8.3885
# Epoch 25/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.8298 - val_loss: 8.3751
# Epoch 26/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.7410 - val_loss: 8.4064
# Epoch 27/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.6331 - val_loss: 8.1668
# Epoch 28/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4805 - val_loss: 7.7754
# Epoch 29/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.6072 - val_loss: 8.2187
# Epoch 30/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.5030 - val_loss: 8.0594
# Epoch 31/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.6498 - val_loss: 8.2068
# Epoch 32/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.5146 - val_loss: 8.0936
# Epoch 33/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4153 - val_loss: 8.0876
# Epoch 34/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4517 - val_loss: 7.9758
# Epoch 35/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.5273 - val_loss: 8.0639
# Epoch 36/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.6768 - val_loss: 8.1166
# Epoch 37/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.6682 - val_loss: 8.0849
# Epoch 38/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.5666 - val_loss: 8.0605
# Epoch 39/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.3580 - val_loss: 7.9002
# Epoch 40/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4205 - val_loss: 7.9088
# Epoch 41/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.3744 - val_loss: 7.8687
# Epoch 42/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4460 - val_loss: 7.8959
# Epoch 43/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4138 - val_loss: 8.1079
# Epoch 44/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4264 - val_loss: 8.1481
# Epoch 45/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.3239 - val_loss: 8.3225
# Epoch 46/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.5763 - val_loss: 8.0985
# Epoch 47/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.3130 - val_loss: 8.4011
# Epoch 48/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.4549 - val_loss: 8.1919
# Epoch 49/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.2816 - val_loss: 8.3304
# Epoch 50/50
# 8/8 [==============================] - 0s 5ms/step - loss: 7.3706 - val_loss: 8.0744
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Loss
# Model losses for 4 different dataset.

# %%
_, axes = plt.subplots(nrows=len(training_sizes), ncols=1, figsize=(10, 10), constrained_layout=True)
axes = axes.flatten()

for i, size in enumerate(training_sizes):
    history = models[size][0]
    history.history['val_loss'] = history.history.get('val_loss', [0])
    bplt.plot_history(history.history, axes=axes[i])

# %% [markdown]
# ### Uploading pretrained model that can predict digits.
# Uploading pretrained model in order to see how much the variational autoencoder were successful in reconstructing digits that can be recognize by MNIST model.
#
# You need to upload **cnn.h5** file inside **Models** folder from provided folder.

# %%
# Loading a pretrained model
model_mnist = load_model('models/cnn.h5')
model_mnist.summary()
# Out:
# 2021-12-20 21:14:12,004 [WARNING] tensorflow: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_1 (Dense)             (None, 128)               1179776
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Predictions based on different sizes of dataset**

# %%
def predict_digit(model_mnist, img):
    digits = np.squeeze(model_mnist.predict(img))
    digit = np.where(digits == np.amax(digits))[0][0]
    return digit

# %%
COLORS = ['spring', 'Wistia', 'gray', 'summer', 'hot',
          'winter', 'afmhot', 'autumn', 'gist_heat', 'copper'] # colormap for digits from 0 to 9

for size_train, (_, vae) in models.items():
    # Example of digits from dataset.
    fig, axes = plt.subplots(10, 10, figsize=(10, 10))

    # Create random numbers for the decoder.
    randoms = np.array([np.random.uniform(-2, 2, latent_dim) for _ in range(10 * 10)]).astype('float32')
    predictions = vae.decoder(randoms).numpy()

    for i, ax in enumerate(tqdm(axes.flatten())):
        ax.xaxis.set_major_locator(plt.NullLocator())
        ax.yaxis.set_major_locator(plt.NullLocator())
        if len(x_test.shape) < 3:
            size = int(np.sqrt(x_test[i].shape[0]))
        else:
            size = x_test.shape[1]
        ax.imshow(predictions[i].reshape(size, size), cmap=COLORS[predict_digit(model_mnist, np.expand_dims(predictions[i], axis=0))])
    fig.suptitle(f'Predictions with size {size_train}')
# Out:
# 100%|██████████| 100/100 [00:04<00:00, 20.99it/s]
# 100%|██████████| 100/100 [00:04<00:00, 24.70it/s]
# 100%|██████████| 100/100 [00:04<00:00, 24.92it/s]
# 100%|██████████| 100/100 [00:04<00:00, 24.76it/s]

# %% [markdown]
# #### Try to change the latent layer to observe how classifying digits with MNIST model is gonna change.

# %%
for size_train, (_, vae) in models.items():
    _, axes = plt.subplots(14, 14, figsize=(10, 10))

    # Create random numbers for the decoder.
    values = np.arange(-3, 4, .5)
    xx, yy = np.meshgrid(values, values)
    input_holder = np.zeros((1, latent_dim))

    for row in range(xx.shape[0]):
        for col in range(xx.shape[1]):
            input_holder[0, :] = [xx[row, col], yy[row, col]]
            axes[row][col].xaxis.set_major_locator(plt.NullLocator())
            axes[row][col].yaxis.set_major_locator(plt.NullLocator())
            img = vae.decoder(input_holder).numpy()

            digit = predict_digit(model_mnist, img)

            axes[row][col].imshow(img.reshape(size, size), cmap=COLORS[digit])

# %%
for size_train, (_, vae) in models.items():
    _, axes = plt.subplots(14, 14, figsize=(10, 10))

    # Create random numbers for the decoder.
    values = np.arange(-14, 14, 2)
    xx, yy = np.meshgrid(values, values)
    input_holder = np.zeros((1, latent_dim))

    for row in range(xx.shape[0]):
        for col in range(xx.shape[1]):
            input_holder[0, :] = [xx[row, col], yy[row, col]]
            axes[row][col].xaxis.set_major_locator(plt.NullLocator())
            axes[row][col].yaxis.set_major_locator(plt.NullLocator())
            img = vae.decoder(input_holder).numpy()

            digit = predict_digit(model_mnist, img)

            axes[row][col].imshow(img.reshape(size, size), cmap=COLORS[digit])
