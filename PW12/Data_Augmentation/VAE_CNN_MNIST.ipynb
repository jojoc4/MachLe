# %% [markdown]
# # **Data Augmentation** using Variational Autoencoder
#
# This notebook will guide you trough the use of a variational convolutional autoencoder in the task of data augmentation. The main objective is to use a convolutional autoencoder to reconstruct of the **"2"** images in the MNIST database in order to augment a database. (You can try different digits)

# %% [markdown]
# ## A little bit about Autoencoder in general
#
# Autoencoder's goal is to learn how to reconstruct the input-data. But how is it helpful? The trick is their structure. The first part of the network is what we refer to as the Encoder. It receives the input and it encodes it in a latent space of a lower dimension. The second part (the Decoder) takes that vector and decode it in order to produce the original input.
#
# Therefore, we can apply them to reproduce the same but a little different or even better data. Examples are:
#
# ***Data Denoising***: Feed them with a noisy image and train them to output the same image but without the noise
#
# ***Training data augmentation***
#
# ***Anomaly Detection***: Train them on a single class so that every anomaly gives a large reconstruction error.
#
# Variational autoencoders are trained to learn the probability distribution that models the input-data and not the function that maps the input and the output. It then samples points from this distribution and feed them to the decoder to generate new input data samples.
#
# One of the key aspects of VAE is the **loss function**. Most commonly, it consists of two components. The reconstruction loss measures how different the reconstructed data are from the original data (binary cross entropy for example).
# [Reference : Sergios Karagiannakos]

# %% [markdown]
# ### Load the packages

# %%
# ============== Packages ===================
# %%capture
# %pip install bff
# %pip install --upgrade tensorflow
import re
import bff
import math
import pickle
import pprint
import statistics
import numpy as np
import collections
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import bff.plot as bplt
from pathlib import Path
import matplotlib as mpl
from itertools import cycle
from datetime import datetime
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from sklearn import preprocessing
import matplotlib.patches as mpatches
from typing import Callable, Dict, List, Sequence, Tuple, Union
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Imports for model
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import mse, binary_crossentropy, MeanSquaredError
from tensorflow.keras.layers import Layer, Dense, Reshape, Conv2D, Conv2DTranspose, Flatten, MaxPooling2D, UpSampling2D

# %% [markdown]
# ### Loading MNIST dataset for digit "***2***"
#
# The MNIST is database of handwritten digits. The digits have been size-normalized and centered in a fixed-size image.
#
# In this section we also split our data into training and testing datasets.
#
# You are able to observe different digits.

# %%
# Loading MNIST dataset for especific number, you can change digit in num variable
num = 2

# MNIST dataset.
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Select only number that choose in num.
train_filter = np.where((y_train == num))
test_filter = np.where((y_test == num))
x_train, y_train = x_train[train_filter], y_train[train_filter]
x_test, y_test = x_test[test_filter], y_test[test_filter]

print(f'Size of train: {y_train.shape}')
print(f'Size of test: {y_test.shape}')

# Resize the images and normalize between [0, 1].
image_size = x_train.shape[1]
x_train = x_train.reshape(x_train.shape[0], image_size, image_size, 1).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], image_size, image_size, 1).astype('float32') / 255
print(f'Shape of training: {x_train.shape}')
print(f'Shape of testing: {x_test.shape}')
# Out:
# Size of train: (5958,)
# Size of test: (1032,)
# Shape of training: (5958, 28, 28, 1)
# Shape of testing: (1032, 28, 28, 1)

# %% [markdown]
# ### Examples of digit ***"2"*** from dataset

# %%
# Examples of 2
_, axes = plt.subplots(10, 10, figsize=(10, 10))

for i, ax in enumerate(tqdm(axes.flatten())):
  ax.xaxis.set_major_locator(plt.NullLocator())
  ax.yaxis.set_major_locator(plt.NullLocator())
  if len(x_train.shape) < 3:
      size = int(np.sqrt(x_train[i].shape[0]))
  else:
      size = x_train.shape[1]
  ax.imshow(x_train[i].reshape(size, size), cmap='gray_r')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 2570.87it/s]

# %% [markdown]
# ### Reconstructing Variational Autoencoder

# %%
class Sampling(Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a serie."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        # By default, random_normal has mean=0 and std=1.0.
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class Encoder(Layer):
    """Maps series to a triplet (z_mean, z_log_var, z)."""

    def __init__(self,
                 latent_dim=2,
                 name='encoder',
                 **kwargs):
        super(Encoder, self).__init__(name=name, **kwargs)
        self.conv_1 = Conv2D(filters=32, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_2 = Conv2D(filters=64, kernel_size=3, activation='relu', strides=2, padding='same')
        self.flatten = Flatten()
        self.dense_before_latent = Dense(16, activation='relu')
        self.dense_mean = Dense(latent_dim, name='z_mean')
        self.dense_log_var = Dense(latent_dim, name='z_log_var')
        self.sampling = Sampling()
  
    def call(self, inputs):
        x = self.conv_1(inputs)
        x = self.conv_2(x)
        shape = K.int_shape(x)
        #print(K.int_shape(x))
        # Generate latent vector.
        x = self.flatten(x)
        x = self.dense_before_latent(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z


class Decoder(Layer):
    """Converts z, the encoded vector, back into a readable series."""
  
    def __init__(self,
                 original_dim,
                 name='decoder',
                 **kwargs):
        super(Decoder, self).__init__(name=name, **kwargs)
        self.dense_proj = Dense(7*7*64, activation='relu')
        self.reshape = Reshape(target_shape=(7, 7, 64))
        self.conv_1 = Conv2DTranspose(filters=64, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_2 = Conv2DTranspose(filters=32, kernel_size=3, activation='relu', strides=2, padding='same')
        self.conv_output = Conv2DTranspose(filters=1, kernel_size=3, activation='sigmoid', padding='same')
  
    def call(self, inputs):
        x = self.dense_proj(inputs)
        x = self.reshape(x)
        x = self.conv_1(x)
        x = self.conv_2(x)
        return self.conv_output(x)


class VariationalAutoEncoder(Model):
    """Combines the encoder and decoder into an end-to-end model for training."""
  
    def __init__(self,
                 original_dim,
                 latent_dim=32,
                 name='autoencoder',
                 **kwargs):
        super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
        self.original_dim = original_dim
        self.encoder = Encoder(latent_dim=latent_dim)
        self.decoder = Decoder(original_dim)
  
    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        reconstructed = self.decoder(z)
        
        # Add KL divergence regularization loss.
        reconstruction_loss = binary_crossentropy(K.flatten(inputs), K.flatten(reconstructed))
        reconstruction_loss *= self.original_dim
        kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
        kl_loss = K.sum(kl_loss, axis=-1)
        kl_loss *= -0.5
        vae_loss = K.mean(reconstruction_loss + kl_loss)
        self.add_loss(vae_loss)
        
        return reconstructed

# %% [markdown]
# ### Different sizes of dataset for fitting the variational autoencoder
#
# In this step, you fit variational autoencoder model to different sizes of train dataset:
#
# 1.   *whole dataset*
# 2.   *1000 samples of dataset*
# 3.   *100 samples of dataset*
# 4.   *10 samples of dataset*
#
#
# Observe different sizes of samples and their model losses.

# %%
models = {}

training_sizes = [x_train.shape[0], 1000, 100, 10] # different sizes of train dataset

for size_training in training_sizes:
    #size_training = x_train.shape[0]
    x_train_filter = x_train[:size_training]

    print(f'Training using {size_training} examples.')
    print(f'Shape of training: {x_train_filter.shape}')

    # Size of layers
    original_dim = x_train_filter.shape[1] # Should be 784.
    latent_dim = 2

    # Parameters for training.
    batch_size = 16 if size_training > 100 else 1
    epochs = 50

    vae = VariationalAutoEncoder(original_dim, 
                                 latent_dim=latent_dim)

    optimizer = Adam(learning_rate=1e-3)

    # Define the Keras TensorBoard callback.
    #logdir="logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")
    #tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

    # Losses are MSE with KL divergence.
    vae.compile(optimizer)
    history = vae.fit(x_train_filter,
                      epochs=epochs, 
                      batch_size=batch_size, 
                      validation_split=0.2, 
                      verbose=1)
                      #callbacks=[tensorboard_callback])
    #plot_model(vae, to_file='vae-cnn.png')
    vae.summary()
    
    models[size_training] = (history, vae)


#plot_model(vae, to_file='11-VAE_MLP_-OBJ.png', show_shapes=True, expand_nested=True)
# Out:
# Training using 5958 examples.
# Shape of training: (5958, 28, 28, 1)
# Epoch 1/50
# 298/298 [==============================] - 7s 9ms/step - loss: 8.6138 - val_loss: 7.3846
# Epoch 2/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.3477 - val_loss: 7.2771
# Epoch 3/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.3031 - val_loss: 7.2506
# Epoch 4/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2904 - val_loss: 7.2541
# Epoch 5/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2888 - val_loss: 7.2614
# Epoch 6/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2866 - val_loss: 7.2482
# Epoch 7/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2830 - val_loss: 7.2475
# Epoch 8/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2857 - val_loss: 7.2452
# Epoch 9/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2844 - val_loss: 7.2543
# Epoch 10/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2837 - val_loss: 7.2660
# Epoch 11/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2818 - val_loss: 7.2451
# Epoch 12/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2815 - val_loss: 7.2389
# Epoch 13/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2828 - val_loss: 7.2460
# Epoch 14/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2818 - val_loss: 7.2507
# Epoch 15/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2823 - val_loss: 7.2463
# Epoch 16/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2838 - val_loss: 7.2510
# Epoch 17/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2798 - val_loss: 7.2395
# Epoch 18/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2810 - val_loss: 7.2456
# Epoch 19/50
# 298/298 [==============================] - 2s 8ms/step - loss: 7.2784 - val_loss: 7.2585
# Epoch 20/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2791 - val_loss: 7.2408
# Epoch 21/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2777 - val_loss: 7.2520
# Epoch 22/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2803 - val_loss: 7.2483
# Epoch 23/50
# 298/298 [==============================] - 2s 7ms/step - loss: 7.2782 - val_loss: 7.2377
# Epoch 24/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2771 - val_loss: 7.2432
# Epoch 25/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2799 - val_loss: 7.2398
# Epoch 26/50
# 298/298 [==============================] - 3s 11ms/step - loss: 7.2781 - val_loss: 7.2411
# Epoch 27/50
# 298/298 [==============================] - 3s 11ms/step - loss: 7.2782 - val_loss: 7.2526
# Epoch 28/50
# 298/298 [==============================] - 3s 11ms/step - loss: 7.2765 - val_loss: 7.2409
# Epoch 29/50
# 298/298 [==============================] - 3s 11ms/step - loss: 7.2781 - val_loss: 7.2365
# Epoch 30/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2793 - val_loss: 7.2443
# Epoch 31/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2770 - val_loss: 7.2762
# Epoch 32/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2772 - val_loss: 7.2480
# Epoch 33/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2770 - val_loss: 7.2412
# Epoch 34/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2768 - val_loss: 7.2492
# Epoch 35/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2760 - val_loss: 7.2383
# Epoch 36/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2755 - val_loss: 7.2389
# Epoch 37/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2749 - val_loss: 7.2376
# Epoch 38/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2756 - val_loss: 7.2385
# Epoch 39/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2763 - val_loss: 7.2457
# Epoch 40/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2751 - val_loss: 7.2474
# Epoch 41/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2757 - val_loss: 7.2405
# Epoch 42/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2729 - val_loss: 7.2371
# Epoch 43/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2745 - val_loss: 7.2469
# Epoch 44/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2738 - val_loss: 7.2648
# Epoch 45/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2762 - val_loss: 7.2355
# Epoch 46/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2730 - val_loss: 7.2364
# Epoch 47/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2742 - val_loss: 7.2371
# Epoch 48/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2742 - val_loss: 7.2381
# Epoch 49/50
# 298/298 [==============================] - 3s 10ms/step - loss: 7.2739 - val_loss: 7.2414
# Epoch 50/50
# 298/298 [==============================] - 3s 8ms/step - loss: 7.2738 - val_loss: 7.2369
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 1000 examples.
# Shape of training: (1000, 28, 28, 1)
# Epoch 1/50
# 50/50 [==============================] - 1s 9ms/step - loss: 12.8882 - val_loss: 8.7230
# Epoch 2/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.9591 - val_loss: 7.6260
# Epoch 3/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.5287 - val_loss: 7.3938
# Epoch 4/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.4154 - val_loss: 7.3500
# Epoch 5/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.3624 - val_loss: 7.3117
# Epoch 6/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.3365 - val_loss: 7.2983
# Epoch 7/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.3181 - val_loss: 7.2822
# Epoch 8/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2961 - val_loss: 7.2493
# Epoch 9/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2819 - val_loss: 7.2312
# Epoch 10/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2769 - val_loss: 7.2262
# Epoch 11/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2591 - val_loss: 7.2204
# Epoch 12/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2498 - val_loss: 7.2167
# Epoch 13/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2535 - val_loss: 7.2155
# Epoch 14/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2334 - val_loss: 7.2025
# Epoch 15/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2342 - val_loss: 7.2319
# Epoch 16/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2313 - val_loss: 7.1988
# Epoch 17/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2271 - val_loss: 7.1884
# Epoch 18/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2255 - val_loss: 7.1961
# Epoch 19/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2235 - val_loss: 7.1857
# Epoch 20/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2274 - val_loss: 7.1987
# Epoch 21/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2145 - val_loss: 7.1841
# Epoch 22/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2216 - val_loss: 7.1957
# Epoch 23/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2173 - val_loss: 7.2146
# Epoch 24/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2304 - val_loss: 7.1876
# Epoch 25/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2208 - val_loss: 7.1757
# Epoch 26/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2207 - val_loss: 7.1829
# Epoch 27/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2206 - val_loss: 7.1951
# Epoch 28/50
# 50/50 [==============================] - 0s 7ms/step - loss: 7.2196 - val_loss: 7.1907
# Epoch 29/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2222 - val_loss: 7.1821
# Epoch 30/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2139 - val_loss: 7.1768
# Epoch 31/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2154 - val_loss: 7.1971
# Epoch 32/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2187 - val_loss: 7.1969
# Epoch 33/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2140 - val_loss: 7.1967
# Epoch 34/50
# 50/50 [==============================] - 0s 6ms/step - loss: 7.2138 - val_loss: 7.1826
# Epoch 35/50
# 50/50 [==============================] - 0s 8ms/step - loss: 7.2159 - val_loss: 7.2101
# Epoch 36/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2147 - val_loss: 7.1817
# Epoch 37/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2106 - val_loss: 7.1743
# Epoch 38/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2208 - val_loss: 7.1906
# Epoch 39/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2112 - val_loss: 7.1975
# Epoch 40/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2222 - val_loss: 7.1819
# Epoch 41/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2098 - val_loss: 7.1695
# Epoch 42/50
# 50/50 [==============================] - 0s 10ms/step - loss: 7.2180 - val_loss: 7.1836
# Epoch 43/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2137 - val_loss: 7.1704
# Epoch 44/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2114 - val_loss: 7.1962
# Epoch 45/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2111 - val_loss: 7.1832
# Epoch 46/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2120 - val_loss: 7.1706
# Epoch 47/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2122 - val_loss: 7.1826
# Epoch 48/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2165 - val_loss: 7.1703
# Epoch 49/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2052 - val_loss: 7.1755
# Epoch 50/50
# 50/50 [==============================] - 0s 9ms/step - loss: 7.2151 - val_loss: 7.1832
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 100 examples.
# Shape of training: (100, 28, 28, 1)
# Epoch 1/50
# 80/80 [==============================] - 1s 8ms/step - loss: 11.9586 - val_loss: 8.9371
# Epoch 2/50
# 80/80 [==============================] - 1s 7ms/step - loss: 8.1547 - val_loss: 8.1534
# Epoch 3/50
# 80/80 [==============================] - 1s 7ms/step - loss: 7.6869 - val_loss: 7.9827
# Epoch 4/50
# 80/80 [==============================] - 1s 6ms/step - loss: 7.6526 - val_loss: 7.9693
# Epoch 5/50
# 80/80 [==============================] - 1s 6ms/step - loss: 7.5013 - val_loss: 7.8591
# Epoch 6/50
# 80/80 [==============================] - 1s 6ms/step - loss: 7.4644 - val_loss: 7.7625
# Epoch 7/50
# 80/80 [==============================] - 1s 6ms/step - loss: 7.4880 - val_loss: 7.8404
# Epoch 8/50
# 80/80 [==============================] - 1s 6ms/step - loss: 7.4326 - val_loss: 7.9048
# Epoch 9/50
# 80/80 [==============================] - 1s 6ms/step - loss: 7.4298 - val_loss: 7.7622
# Epoch 10/50
# 80/80 [==============================] - 1s 7ms/step - loss: 7.3402 - val_loss: 7.8673
# Epoch 11/50
# 80/80 [==============================] - 1s 7ms/step - loss: 7.4392 - val_loss: 7.8043
# Epoch 12/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3649 - val_loss: 7.7161
# Epoch 13/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3399 - val_loss: 7.6680
# Epoch 14/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3463 - val_loss: 7.6991
# Epoch 15/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3781 - val_loss: 7.7427
# Epoch 16/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3300 - val_loss: 7.6753
# Epoch 17/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3328 - val_loss: 7.7255
# Epoch 18/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3457 - val_loss: 7.8641
# Epoch 19/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3464 - val_loss: 7.6965
# Epoch 20/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3990 - val_loss: 7.7721
# Epoch 21/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2896 - val_loss: 7.6727
# Epoch 22/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3495 - val_loss: 7.6688
# Epoch 23/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3234 - val_loss: 7.7504
# Epoch 24/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3437 - val_loss: 7.7542
# Epoch 25/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3726 - val_loss: 7.8698
# Epoch 26/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3231 - val_loss: 7.7749
# Epoch 27/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3155 - val_loss: 7.7187
# Epoch 28/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2905 - val_loss: 7.8653
# Epoch 29/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3139 - val_loss: 7.7540
# Epoch 30/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2980 - val_loss: 7.7899
# Epoch 31/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2757 - val_loss: 7.6490
# Epoch 32/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2924 - val_loss: 7.7021
# Epoch 33/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2806 - val_loss: 7.8412
# Epoch 34/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3434 - val_loss: 7.7318
# Epoch 35/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3155 - val_loss: 7.7419
# Epoch 36/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2818 - val_loss: 7.8323
# Epoch 37/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3095 - val_loss: 7.7167
# Epoch 38/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3180 - val_loss: 7.7415
# Epoch 39/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2923 - val_loss: 7.7205
# Epoch 40/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3048 - val_loss: 7.7516
# Epoch 41/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2714 - val_loss: 7.7348
# Epoch 42/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2789 - val_loss: 7.7029
# Epoch 43/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3120 - val_loss: 7.7027
# Epoch 44/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3016 - val_loss: 7.7227
# Epoch 45/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3169 - val_loss: 7.7992
# Epoch 46/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2767 - val_loss: 7.7300
# Epoch 47/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2900 - val_loss: 7.7350
# Epoch 48/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.3604 - val_loss: 7.7171
# Epoch 49/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2896 - val_loss: 7.8221
# Epoch 50/50
# 80/80 [==============================] - 0s 5ms/step - loss: 7.2852 - val_loss: 7.7890
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________
# Training using 10 examples.
# Shape of training: (10, 28, 28, 1)
# Epoch 1/50
# 8/8 [==============================] - 1s 23ms/step - loss: 19.0402 - val_loss: 18.5232
# Epoch 2/50
# 8/8 [==============================] - 0s 7ms/step - loss: 17.2062 - val_loss: 15.4572
# Epoch 3/50
# 8/8 [==============================] - 0s 7ms/step - loss: 13.8755 - val_loss: 12.5352
# Epoch 4/50
# 8/8 [==============================] - 0s 7ms/step - loss: 12.4086 - val_loss: 13.7355
# Epoch 5/50
# 8/8 [==============================] - 0s 7ms/step - loss: 12.3664 - val_loss: 10.6138
# Epoch 6/50
# 8/8 [==============================] - 0s 7ms/step - loss: 11.8622 - val_loss: 9.9709
# Epoch 7/50
# 8/8 [==============================] - 0s 7ms/step - loss: 10.5002 - val_loss: 9.8198
# Epoch 8/50
# 8/8 [==============================] - 0s 7ms/step - loss: 9.6721 - val_loss: 9.3542
# Epoch 9/50
# 8/8 [==============================] - 0s 7ms/step - loss: 9.3835 - val_loss: 8.5678
# Epoch 10/50
# 8/8 [==============================] - 0s 7ms/step - loss: 9.2694 - val_loss: 8.5331
# Epoch 11/50
# 8/8 [==============================] - 0s 7ms/step - loss: 8.4818 - val_loss: 8.2875
# Epoch 12/50
# 8/8 [==============================] - 0s 7ms/step - loss: 8.2961 - val_loss: 8.3707
# Epoch 13/50
# 8/8 [==============================] - 0s 7ms/step - loss: 8.2448 - val_loss: 8.1771
# Epoch 14/50
# 8/8 [==============================] - 0s 7ms/step - loss: 8.1227 - val_loss: 8.0242
# Epoch 15/50
# 8/8 [==============================] - 0s 7ms/step - loss: 8.1425 - val_loss: 8.4519
# Epoch 16/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.8185 - val_loss: 8.3506
# Epoch 17/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.8326 - val_loss: 8.5164
# Epoch 18/50
# 8/8 [==============================] - 0s 7ms/step - loss: 8.2484 - val_loss: 8.0746
# Epoch 19/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.8876 - val_loss: 8.2572
# Epoch 20/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.7625 - val_loss: 8.1752
# Epoch 21/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.9405 - val_loss: 8.3876
# Epoch 22/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.8339 - val_loss: 8.0706
# Epoch 23/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.9697 - val_loss: 7.6570
# Epoch 24/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.7426 - val_loss: 7.9967
# Epoch 25/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.5260 - val_loss: 7.9279
# Epoch 26/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4067 - val_loss: 8.5712
# Epoch 27/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.9783 - val_loss: 7.8577
# Epoch 28/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4983 - val_loss: 7.9167
# Epoch 29/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4187 - val_loss: 7.7896
# Epoch 30/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.7506 - val_loss: 7.7981
# Epoch 31/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.7530 - val_loss: 8.4683
# Epoch 32/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.7319 - val_loss: 7.7460
# Epoch 33/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.6474 - val_loss: 7.8933
# Epoch 34/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.5276 - val_loss: 8.0178
# Epoch 35/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4035 - val_loss: 8.1081
# Epoch 36/50
# 8/8 [==============================] - 0s 8ms/step - loss: 7.8631 - val_loss: 7.9199
# Epoch 37/50
# 8/8 [==============================] - 0s 8ms/step - loss: 7.7384 - val_loss: 8.0519
# Epoch 38/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.6175 - val_loss: 8.1502
# Epoch 39/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.5569 - val_loss: 8.0229
# Epoch 40/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.5335 - val_loss: 7.9428
# Epoch 41/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.6664 - val_loss: 8.0566
# Epoch 42/50
# 8/8 [==============================] - 0s 8ms/step - loss: 7.4053 - val_loss: 7.8920
# Epoch 43/50
# 8/8 [==============================] - 0s 8ms/step - loss: 7.4750 - val_loss: 8.1313
# Epoch 44/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4745 - val_loss: 7.9840
# Epoch 45/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4824 - val_loss: 7.8222
# Epoch 46/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4660 - val_loss: 7.9914
# Epoch 47/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.3807 - val_loss: 8.0983
# Epoch 48/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4467 - val_loss: 8.0222
# Epoch 49/50
# 8/8 [==============================] - 0s 8ms/step - loss: 7.6673 - val_loss: 8.3498
# Epoch 50/50
# 8/8 [==============================] - 0s 7ms/step - loss: 7.4295 - val_loss: 7.8387
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder (Encoder)           multiple                  69076
#
#  decoder (Decoder)           multiple                  65089
#
# =================================================================
# Total params: 134,165
# Trainable params: 134,165
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Loss
# Model losses for 4 different dataset.

# %%
_, axes = plt.subplots(nrows=len(training_sizes), ncols=1, figsize=(10, 10), constrained_layout=True)
axes = axes.flatten()

for i, size in enumerate(training_sizes):
    history = models[size][0]
    history.history['val_loss'] = history.history.get('val_loss', [0])
    bplt.plot_history(history.history, axes=axes[i])

# %% [markdown]
# ### Uploading pretrained model that can predict digits.
# Uploading pretrained model in order to see how much the variational autoencoder were successful in reconstructing digits that can be recognize by MNIST model.
#
# You need to upload **cnn.h5** file inside **Models** folder from provided folder.

# %%
# Loading a pretrained model
model_mnist = load_model('models/cnn.h5')
model_mnist.summary()
# Out:
# 2021-12-14 16:56:28,624 [WARNING] tensorflow: Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_1 (Dense)             (None, 128)               1179776
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Predictions based on different sizes of dataset**

# %%
def predict_digit(model_mnist, img):
    digits = np.squeeze(model_mnist.predict(img))
    digit = np.where(digits == np.amax(digits))[0][0]
    return digit

# %%
COLORS = ['spring', 'Wistia', 'gray', 'summer', 'hot',
          'winter', 'afmhot', 'autumn', 'gist_heat', 'copper'] # colormap for digits from 0 to 9

for size_train, (_, vae) in models.items():
    # Example of digits from dataset.
    fig, axes = plt.subplots(10, 10, figsize=(10, 10))

    # Create random numbers for the decoder.
    randoms = np.array([np.random.uniform(-2, 2, latent_dim) for _ in range(10 * 10)]).astype('float32')
    predictions = vae.decoder(randoms).numpy()

    for i, ax in enumerate(tqdm(axes.flatten())):
        ax.xaxis.set_major_locator(plt.NullLocator())
        ax.yaxis.set_major_locator(plt.NullLocator())
        if len(x_test.shape) < 3:
            size = int(np.sqrt(x_test[i].shape[0]))
        else:
            size = x_test.shape[1]
        ax.imshow(predictions[i].reshape(size, size), cmap=COLORS[predict_digit(model_mnist, np.expand_dims(predictions[i], axis=0))])
    fig.suptitle(f'Predictions with size {size_train}')
# Out:
# 100%|██████████| 100/100 [00:03<00:00, 32.93it/s]
# 100%|██████████| 100/100 [00:03<00:00, 31.85it/s]
# 100%|██████████| 100/100 [00:02<00:00, 33.55it/s]
# 100%|██████████| 100/100 [00:02<00:00, 33.46it/s]

# %% [markdown]
# #### Try to change the latent layer to observe how classifying digits with MNIST model is gonna change.

# %%
for size_train, (_, vae) in models.items():
    _, axes = plt.subplots(14, 14, figsize=(10, 10))

    # Create random numbers for the decoder.
    values = np.arange(-3, 4, .5)
    xx, yy = np.meshgrid(values, values)
    input_holder = np.zeros((1, latent_dim))

    for row in range(xx.shape[0]):
        for col in range(xx.shape[1]):
            input_holder[0, :] = [xx[row, col], yy[row, col]]
            axes[row][col].xaxis.set_major_locator(plt.NullLocator())
            axes[row][col].yaxis.set_major_locator(plt.NullLocator())
            img = vae.decoder(input_holder).numpy()

            digit = predict_digit(model_mnist, img)

            axes[row][col].imshow(img.reshape(size, size), cmap=COLORS[digit])

# %%
for size_train, (_, vae) in models.items():
    _, axes = plt.subplots(14, 14, figsize=(10, 10))

    # Create random numbers for the decoder.
    values = np.arange(-7, 7, 1)
    xx, yy = np.meshgrid(values, values)
    input_holder = np.zeros((1, latent_dim))

    for row in range(xx.shape[0]):
        for col in range(xx.shape[1]):
            input_holder[0, :] = [xx[row, col], yy[row, col]]
            axes[row][col].xaxis.set_major_locator(plt.NullLocator())
            axes[row][col].yaxis.set_major_locator(plt.NullLocator())
            img = vae.decoder(input_holder).numpy()

            digit = predict_digit(model_mnist, img)

            axes[row][col].imshow(img.reshape(size, size), cmap=COLORS[digit])
