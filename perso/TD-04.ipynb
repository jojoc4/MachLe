# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("x02.csv", names=["gender", "age", "head_size", "brain_weight"])
dataset.head()
# Out:
#    gender  age  head_size  brain_weight
# 0       1    1       4512          1530
# 1       1    1       3738          1297
# 2       1    1       4261          1335
# 3       1    1       3777          1282
# 4       1    1       4177          1590

# %%
x = dataset["brain_weight"].values * 1.0
y = dataset["head_size"].values * 1.0

# %%
len(x)
len(y)
# Out:
# 237

# %%
type(x[0])
# Out:
# numpy.float64

# %%
plt.scatter(x, y)
plt.title("Head size as f(brain weight)")
plt.xlabel("brain weight (g)")
plt.ylabel("head size (cm3)")
# Out:
# Text(0, 0.5, 'head size (cm3)')

# %%
thetas = np.polyfit(x, y, 1)
h=np.poly1d(thetas)
h(1400)
# Out:
# 3918.243865477836

# %%
y_hat=h(x)

plt.scatter(x, y, label="row datas")
plt.plot(x, y_hat, color="red", label="linear regression y = h(x)")
plt.title("Head size as f(brain weight)")
plt.xlabel("brain weight (g)")
plt.ylabel("head size (cm3)")
plt.legend()

# %%
thetas2 = np.polyfit(x, y, 2)
h2=np.poly1d(thetas2)
y_hat2=h2(x)

plt.scatter(x, y, label="row datas")
plt.plot(x, y_hat, color="red", label="linear regression y = h(x)")
plt.plot(x, y_hat2, color="green", label="lsecond order polynomial regression y = h2(x)")
plt.title("Head size as f(brain weight)")
plt.xlabel("brain weight (g)")
plt.ylabel("head size (cm3)")
plt.legend()
